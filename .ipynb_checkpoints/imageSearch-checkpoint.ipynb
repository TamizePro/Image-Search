# %%
#importing useful modules
import requests,bs4,os

url = 'https://imgur.com/search?q='
inquiry = input('What kind of images are you looking for?: ')
result = requests.get(url + inquiry)
result.raise_for_status()
page = bs4.BeautifulSoup(result.text)

images = page.select('img')
if images == []:
    print('No images found for your inquiry')
else:
    #creating a folder where downloaded images will appear
    os.makedirs('images\\' + inquiry,exist_ok = True)
    
    for i in range(3,len(images)):
        #downloading each image
        imageUrl = 'https:' + images[i].get('src')
        print(imageUrl)
        image = requests.get(imageUrl)
        image.raise_for_status()
        
        #correct the path 
        imagePath = list('images\\' + inquiry)
        
        for c in imagePath:
            if c == '/':
                c = '\\'
                
        #saving each image
        imageFile = open(os.path.join(''.join(imagePath),os.path.basename(imageUrl)),'wb')
        
        for chunk in image.iter_content(100000):
            imageFile.write(chunk)
        imageFile.close()
# Out:
# What kind of images are you looking for?: Bible
# https://i.imgur.com/83PXpGbb.jpg
# https://i.imgur.com/UiVBuIWb.jpg
# https://i.imgur.com/O5VoTxjb.jpg
# https://i.imgur.com/kW9ecjqb.jpg
# https://i.imgur.com/tJxssHSb.jpg
# https://i.imgur.com/cAKKZSub.jpg
# https://i.imgur.com/cyAhhxgb.jpg
# https://i.imgur.com/MNEmsf5b.jpg
# https://i.imgur.com/LB1Dw13b.jpg
# https://i.imgur.com/Vow0T85b.jpg
# https://i.imgur.com/Z0oj9Llb.jpg
# https://i.imgur.com/7ICKUfzb.jpg
# https://i.imgur.com/e8jY1nzb.jpg
# https://i.imgur.com/Cupsix2b.jpg
# https://i.imgur.com/f8jKYbqb.jpg
# https://i.imgur.com/wsVEfhNb.jpg
# https://i.imgur.com/Qov9GuBb.jpg
# https://i.imgur.com/8Hu09Seb.jpg
# https://i.imgur.com/D6vlPPUb.jpg
# https://i.imgur.com/DuT34Klb.jpg
# https://i.imgur.com/LXIV8QSb.jpg
# https://i.imgur.com/38ZyYk9b.jpg
# https://i.imgur.com/2PxR5Qzb.jpg
# https://i.imgur.com/2ANYoEKb.jpg
# https://i.imgur.com/Itx8EJPb.jpg
# https://i.imgur.com/rw93jjlb.jpg
# https://i.imgur.com/OARN1ZFb.jpg
# https://i.imgur.com/wj5aJiAb.jpg
# https://i.imgur.com/hH91o2kb.jpg
# https://i.imgur.com/LyMLlqQb.jpg
# https://i.imgur.com/QozO7ZPb.jpg
# https://i.imgur.com/IOo9tctb.jpg
# https://i.imgur.com/XsUtiKzb.jpg
# https://i.imgur.com/zSRGYupb.jpg
# https://i.imgur.com/cwoA1iKb.jpg
# https://i.imgur.com/eVZ5Iq8b.jpg
# https://i.imgur.com/B8WFMYBb.jpg
# https://i.imgur.com/1JOUMHyb.jpg
# https://i.imgur.com/JREBB6fb.jpg
# https://i.imgur.com/5SDE1eRb.jpg
# https://i.imgur.com/tklhKtib.jpg
# https://i.imgur.com/Xzw5tKRb.jpg
# https://i.imgur.com/ufNkjgCb.jpg
# https://i.imgur.com/8ehlUcfb.jpg
# https://i.imgur.com/8Mnor0hb.jpg
# https://i.imgur.com/M9p9N2ib.jpg
# https://i.imgur.com/aZKK2lQb.jpg
# https://i.imgur.com/2GNdzvcb.jpg
# https://i.imgur.com/VHb5oXrb.jpg
# https://i.imgur.com/ojLObqlb.jpg
# https://i.imgur.com/d2OXX4Lb.jpg
# https://i.imgur.com/gcEiWiSb.jpg
# https://i.imgur.com/Z6fBm47b.jpg
# https://i.imgur.com/LDsN0Uwb.jpg
# https://i.imgur.com/JjZ8rPhb.jpg
# https://i.imgur.com/DQH01w8b.jpg
# https://i.imgur.com/cNjmAMTb.jpg
# https://i.imgur.com/LDE3ABub.jpg
# https://i.imgur.com/jKSQSgSb.jpg
# https://s.imgur.com/images/loaders/ddddd1_181817/48.gif

# %%
import requests,bs4,os
